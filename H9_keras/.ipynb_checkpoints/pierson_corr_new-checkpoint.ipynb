# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from matplotlib import pyplot
from scipy.stats import spearmanr
from scipy.stats import pearsonr
import keras.backend as K
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.

# %%
def pierson_loss(y_true: tf.Tensor,
                                 y_pred: tf.Tensor) -> float:
    """Pearson correlation coefficient"""

    x = y_true
    y = y_pred
    xm, ym = x - K.mean(x), y - K.mean(y)
    r_num = K.sum(tf.multiply(xm, ym))
    r_den = K.sqrt(tf.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / (r_den + K.epsilon())
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    
    return 1 - K.square(r)

# %%
def pierson_metric(y_true: tf.Tensor,
                                 y_pred: tf.Tensor) -> float:
    """Pearson correlation coefficient"""

    x = y_true
    y = y_pred
    xm, ym = x - K.mean(x), y - K.mean(y)
    r_num = K.sum(tf.multiply(xm, ym))
    r_den = K.sqrt(tf.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / (r_den + K.epsilon())
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    
    return 1 - K.square(r)

# %%
num_features = 20
# generate regression dataset
X, y = make_regression(n_samples=1000, n_features=num_features, noise=0.1, random_state=1)

# split into train and test
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# reshape 1d arrays to 2d arrays
trainy = trainy.reshape(len(trainy), 1)
testy = testy.reshape(len(trainy), 1)

# create scaler
scaler = StandardScaler()
# fit scaler on training dataset
scaler.fit(trainy)
# transform training dataset
trainy = scaler.transform(trainy)
# transform test dataset
testy = scaler.transform(testy)

# fit scaler on training dataset
scaler.fit(trainX)
# transform training dataset
trainX = scaler.transform(trainX)
# transform test dataset
testX = scaler.transform(testX)

# %%
# mlp with scaled outputs on the regression problem
# define model
model = Sequential()
model.add(Dense(25, input_dim=20, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(1, activation='linear'))
# compile model using pierson_correlation los function
model.compile(loss=pierson_loss, optimizer=SGD(lr=0.01, momentum=0.9), metrics=[pierson_metric])
#model.compile(loss='mean_squared_error', optimizer=SGD(lr=0.01, momentum=0.9))
# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=1)
# evaluate the model
train_mse = model.evaluate(trainX, trainy, verbose=1)
test_mse = model.evaluate(testX, testy, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_mse[1], test_mse[1])) #when using custom loss and custom metric
#print('Train: %.3f, Test: %.3f' % (train_mse, test_mse)) 
#plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Train on 500 samples, validate on 500 samples
# Epoch 1/100
# 500/500 [==============================] - 0s 373us/step - loss: 0.9439 - pierson_metric: 0.9439 - val_loss: 0.9141 - val_pierson_metric: 0.9141
# Epoch 2/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.7982 - pierson_metric: 0.7982 - val_loss: 0.5364 - val_pierson_metric: 0.5364
# Epoch 3/100
# 500/500 [==============================] - 0s 41us/step - loss: 0.4124 - pierson_metric: 0.4124 - val_loss: 0.2125 - val_pierson_metric: 0.2125
# Epoch 4/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.1746 - pierson_metric: 0.1746 - val_loss: 0.1174 - val_pierson_metric: 0.1174
# Epoch 5/100
# 500/500 [==============================] - 0s 42us/step - loss: 0.0956 - pierson_metric: 0.0956 - val_loss: 0.0856 - val_pierson_metric: 0.0856
# Epoch 6/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0723 - pierson_metric: 0.0723 - val_loss: 0.0695 - val_pierson_metric: 0.0695
# Epoch 7/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0598 - pierson_metric: 0.0598 - val_loss: 0.0593 - val_pierson_metric: 0.0593
# Epoch 8/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0494 - pierson_metric: 0.0494 - val_loss: 0.0527 - val_pierson_metric: 0.0527
# Epoch 9/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0415 - pierson_metric: 0.0415 - val_loss: 0.0476 - val_pierson_metric: 0.0476
# Epoch 10/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0388 - pierson_metric: 0.0388 - val_loss: 0.0432 - val_pierson_metric: 0.0432
# Epoch 11/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0334 - pierson_metric: 0.0334 - val_loss: 0.0395 - val_pierson_metric: 0.0395
# Epoch 12/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0308 - pierson_metric: 0.0308 - val_loss: 0.0364 - val_pierson_metric: 0.0364
# Epoch 13/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0284 - pierson_metric: 0.0284 - val_loss: 0.0338 - val_pierson_metric: 0.0338
# Epoch 14/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0251 - pierson_metric: 0.0251 - val_loss: 0.0311 - val_pierson_metric: 0.0311
# Epoch 15/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0229 - pierson_metric: 0.0229 - val_loss: 0.0293 - val_pierson_metric: 0.0293
# Epoch 16/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0202 - pierson_metric: 0.0202 - val_loss: 0.0274 - val_pierson_metric: 0.0274
# Epoch 17/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0208 - pierson_metric: 0.0208 - val_loss: 0.0259 - val_pierson_metric: 0.0259
# Epoch 18/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0182 - pierson_metric: 0.0182 - val_loss: 0.0245 - val_pierson_metric: 0.0245
# Epoch 19/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0175 - pierson_metric: 0.0175 - val_loss: 0.0233 - val_pierson_metric: 0.0233
# Epoch 20/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0168 - pierson_metric: 0.0168 - val_loss: 0.0221 - val_pierson_metric: 0.0221
# Epoch 21/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0163 - pierson_metric: 0.0163 - val_loss: 0.0210 - val_pierson_metric: 0.0210
# Epoch 22/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0152 - pierson_metric: 0.0152 - val_loss: 0.0202 - val_pierson_metric: 0.0202
# Epoch 23/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0140 - pierson_metric: 0.0140 - val_loss: 0.0192 - val_pierson_metric: 0.0192
# Epoch 24/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0133 - pierson_metric: 0.0133 - val_loss: 0.0184 - val_pierson_metric: 0.0184
# Epoch 25/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0132 - pierson_metric: 0.0132 - val_loss: 0.0176 - val_pierson_metric: 0.0176
# Epoch 26/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0120 - pierson_metric: 0.0120 - val_loss: 0.0171 - val_pierson_metric: 0.0171
# Epoch 27/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0121 - pierson_metric: 0.0121 - val_loss: 0.0165 - val_pierson_metric: 0.0165
# Epoch 28/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0115 - pierson_metric: 0.0115 - val_loss: 0.0159 - val_pierson_metric: 0.0159
# Epoch 29/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0115 - pierson_metric: 0.0115 - val_loss: 0.0155 - val_pierson_metric: 0.0155
# Epoch 30/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0104 - pierson_metric: 0.0104 - val_loss: 0.0150 - val_pierson_metric: 0.0150
# Epoch 31/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0106 - pierson_metric: 0.0106 - val_loss: 0.0146 - val_pierson_metric: 0.0146
# Epoch 32/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0099 - pierson_metric: 0.0099 - val_loss: 0.0141 - val_pierson_metric: 0.0141
# Epoch 33/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0095 - pierson_metric: 0.0095 - val_loss: 0.0138 - val_pierson_metric: 0.0138
# Epoch 34/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0091 - pierson_metric: 0.0091 - val_loss: 0.0133 - val_pierson_metric: 0.0133
# Epoch 35/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0096 - pierson_metric: 0.0096 - val_loss: 0.0130 - val_pierson_metric: 0.0130
# Epoch 36/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0089 - pierson_metric: 0.0089 - val_loss: 0.0128 - val_pierson_metric: 0.0128
# Epoch 37/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0087 - pierson_metric: 0.0087 - val_loss: 0.0123 - val_pierson_metric: 0.0123
# Epoch 38/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0087 - pierson_metric: 0.0087 - val_loss: 0.0121 - val_pierson_metric: 0.0121
# Epoch 39/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0086 - pierson_metric: 0.0086 - val_loss: 0.0118 - val_pierson_metric: 0.0118
# Epoch 40/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0079 - pierson_metric: 0.0079 - val_loss: 0.0115 - val_pierson_metric: 0.0115
# Epoch 41/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0072 - pierson_metric: 0.0072 - val_loss: 0.0112 - val_pierson_metric: 0.0112
# Epoch 42/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0071 - pierson_metric: 0.0071 - val_loss: 0.0109 - val_pierson_metric: 0.0109
# Epoch 43/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0073 - pierson_metric: 0.0073 - val_loss: 0.0106 - val_pierson_metric: 0.0106
# Epoch 44/100
# 500/500 [==============================] - ETA: 0s - loss: 0.0082 - pierson_metric: 0.00 - 0s 36us/step - loss: 0.0073 - pierson_metric: 0.0073 - val_loss: 0.0104 - val_pierson_metric: 0.0104
# Epoch 45/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0067 - pierson_metric: 0.0067 - val_loss: 0.0102 - val_pierson_metric: 0.0102
# Epoch 46/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0065 - pierson_metric: 0.0065 - val_loss: 0.0101 - val_pierson_metric: 0.0101
# Epoch 47/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0066 - pierson_metric: 0.0066 - val_loss: 0.0099 - val_pierson_metric: 0.0099
# Epoch 48/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0061 - pierson_metric: 0.0061 - val_loss: 0.0097 - val_pierson_metric: 0.0097
# Epoch 49/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0068 - pierson_metric: 0.0068 - val_loss: 0.0096 - val_pierson_metric: 0.0096
# Epoch 50/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0058 - pierson_metric: 0.0058 - val_loss: 0.0093 - val_pierson_metric: 0.0093
# Epoch 51/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0061 - pierson_metric: 0.0061 - val_loss: 0.0092 - val_pierson_metric: 0.0092
# Epoch 52/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0060 - pierson_metric: 0.0060 - val_loss: 0.0090 - val_pierson_metric: 0.0090
# Epoch 53/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0057 - pierson_metric: 0.0057 - val_loss: 0.0089 - val_pierson_metric: 0.0089
# Epoch 54/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0055 - pierson_metric: 0.0055 - val_loss: 0.0088 - val_pierson_metric: 0.0088
# Epoch 55/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0055 - pierson_metric: 0.0055 - val_loss: 0.0086 - val_pierson_metric: 0.0086
# Epoch 56/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0054 - pierson_metric: 0.0054 - val_loss: 0.0084 - val_pierson_metric: 0.0084
# Epoch 57/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0054 - pierson_metric: 0.0054 - val_loss: 0.0083 - val_pierson_metric: 0.0083
# Epoch 58/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0054 - pierson_metric: 0.0054 - val_loss: 0.0082 - val_pierson_metric: 0.0082
# Epoch 59/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0049 - pierson_metric: 0.0049 - val_loss: 0.0081 - val_pierson_metric: 0.0081
# Epoch 60/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0049 - pierson_metric: 0.0049 - val_loss: 0.0080 - val_pierson_metric: 0.0080
# Epoch 61/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0049 - pierson_metric: 0.0049 - val_loss: 0.0079 - val_pierson_metric: 0.0079
# Epoch 62/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0048 - pierson_metric: 0.0048 - val_loss: 0.0078 - val_pierson_metric: 0.0078
# Epoch 63/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0048 - pierson_metric: 0.0048 - val_loss: 0.0077 - val_pierson_metric: 0.0077
# Epoch 64/100
# 500/500 [==============================] - 0s 42us/step - loss: 0.0045 - pierson_metric: 0.0045 - val_loss: 0.0076 - val_pierson_metric: 0.0076
# Epoch 65/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0045 - pierson_metric: 0.0045 - val_loss: 0.0075 - val_pierson_metric: 0.0075
# Epoch 66/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0045 - pierson_metric: 0.0045 - val_loss: 0.0073 - val_pierson_metric: 0.0073
# Epoch 67/100
# 500/500 [==============================] - 0s 44us/step - loss: 0.0045 - pierson_metric: 0.0045 - val_loss: 0.0072 - val_pierson_metric: 0.0072
# Epoch 68/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0043 - pierson_metric: 0.0043 - val_loss: 0.0071 - val_pierson_metric: 0.0071
# Epoch 69/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0047 - pierson_metric: 0.0047 - val_loss: 0.0071 - val_pierson_metric: 0.0071
# Epoch 70/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0046 - pierson_metric: 0.0046 - val_loss: 0.0070 - val_pierson_metric: 0.0070
# Epoch 71/100
# 500/500 [==============================] - 0s 42us/step - loss: 0.0041 - pierson_metric: 0.0041 - val_loss: 0.0068 - val_pierson_metric: 0.0068
# Epoch 72/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0043 - pierson_metric: 0.0043 - val_loss: 0.0067 - val_pierson_metric: 0.0067
# Epoch 73/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0039 - pierson_metric: 0.0039 - val_loss: 0.0067 - val_pierson_metric: 0.0067
# Epoch 74/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0042 - pierson_metric: 0.0042 - val_loss: 0.0066 - val_pierson_metric: 0.0066
# Epoch 75/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0037 - pierson_metric: 0.0037 - val_loss: 0.0065 - val_pierson_metric: 0.0065
# Epoch 76/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0037 - pierson_metric: 0.0037 - val_loss: 0.0064 - val_pierson_metric: 0.0064
# Epoch 77/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0039 - pierson_metric: 0.0039 - val_loss: 0.0063 - val_pierson_metric: 0.0063
# Epoch 78/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0037 - pierson_metric: 0.0037 - val_loss: 0.0063 - val_pierson_metric: 0.0063
# Epoch 79/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0035 - pierson_metric: 0.0035 - val_loss: 0.0062 - val_pierson_metric: 0.0062
# Epoch 80/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0038 - pierson_metric: 0.0038 - val_loss: 0.0062 - val_pierson_metric: 0.0062
# Epoch 81/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0038 - pierson_metric: 0.0038 - val_loss: 0.0061 - val_pierson_metric: 0.0061
# Epoch 82/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0037 - pierson_metric: 0.0037 - val_loss: 0.0060 - val_pierson_metric: 0.0060
# Epoch 83/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0034 - pierson_metric: 0.0034 - val_loss: 0.0060 - val_pierson_metric: 0.0060
# Epoch 84/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0034 - pierson_metric: 0.0034 - val_loss: 0.0059 - val_pierson_metric: 0.0059
# Epoch 85/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0035 - pierson_metric: 0.0035 - val_loss: 0.0058 - val_pierson_metric: 0.0058
# Epoch 86/100
# 500/500 [==============================] - 0s 34us/step - loss: 0.0035 - pierson_metric: 0.0035 - val_loss: 0.0058 - val_pierson_metric: 0.0058
# Epoch 87/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0035 - pierson_metric: 0.0035 - val_loss: 0.0057 - val_pierson_metric: 0.0057
# Epoch 88/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0033 - pierson_metric: 0.0033 - val_loss: 0.0056 - val_pierson_metric: 0.0056
# Epoch 89/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0031 - pierson_metric: 0.0031 - val_loss: 0.0056 - val_pierson_metric: 0.0056
# Epoch 90/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0033 - pierson_metric: 0.0033 - val_loss: 0.0056 - val_pierson_metric: 0.0056
# Epoch 91/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0030 - pierson_metric: 0.0030 - val_loss: 0.0055 - val_pierson_metric: 0.0055
# Epoch 92/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0035 - pierson_metric: 0.0035 - val_loss: 0.0054 - val_pierson_metric: 0.0054
# Epoch 93/100
# 500/500 [==============================] - 0s 34us/step - loss: 0.0032 - pierson_metric: 0.0032 - val_loss: 0.0054 - val_pierson_metric: 0.0054
# Epoch 94/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0031 - pierson_metric: 0.0031 - val_loss: 0.0053 - val_pierson_metric: 0.0053
# Epoch 95/100
# 500/500 [==============================] - 0s 36us/step - loss: 0.0030 - pierson_metric: 0.0030 - val_loss: 0.0052 - val_pierson_metric: 0.0052
# Epoch 96/100
# 500/500 [==============================] - 0s 34us/step - loss: 0.0030 - pierson_metric: 0.0030 - val_loss: 0.0052 - val_pierson_metric: 0.0052
# Epoch 97/100
# 500/500 [==============================] - 0s 40us/step - loss: 0.0028 - pierson_metric: 0.0028 - val_loss: 0.0052 - val_pierson_metric: 0.0052
# Epoch 98/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0028 - pierson_metric: 0.0028 - val_loss: 0.0051 - val_pierson_metric: 0.0051
# Epoch 99/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0029 - pierson_metric: 0.0029 - val_loss: 0.0050 - val_pierson_metric: 0.0050
# Epoch 100/100
# 500/500 [==============================] - 0s 38us/step - loss: 0.0030 - pierson_metric: 0.0030 - val_loss: 0.0050 - val_pierson_metric: 0.0050
# 500/500 [==============================] - 0s 14us/step
# 500/500 [==============================] - 0s 14us/step
# Train: 0.003, Test: 0.005

# %% [markdown]
# https://github.com/aponte411/numerai_train/blob/master/metrics.py
# https://pretagteam.com/question/how-to-compute-spearman-correlation-in-tensorflow
# https://www.py4u.net/discuss/199027
